# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import numpy as np

# %%
cars=pd.read_csv(r"C:\Users\mvdsa\Downloads\Cars.csv")
cars.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
cars.shape
# Out:
# (81, 5)

# %%
cars.isnull().sum()
# Out:
# HP     0
# MPG    0
# VOL    0
# SP     0
# WT     0
# dtype: int64

# %%
cars.sample(11)
# Out:
#      HP        MPG  VOL          SP         WT
# 19   90  38.901834  103  118.472936  33.516974
# 17   92  39.354094   50  117.598513  16.194122
# 60  145  27.354265  111  130.208698  36.888153
# 72  162  23.203569  132  133.140074  43.353123
# 49  115  29.629936  101  118.288996  33.458472
# 31   84  39.431235  101  112.288996  33.234361
# 16   78  42.789909   91  114.369293  29.535784
# 39  130  31.014131   92  128.461264  30.115434
# 30   84  39.431235  114  113.484609  37.042350
# 7    62  46.716554   50  102.598513  15.847758
# 52  115  29.629936  124  120.404312  40.398164

# %%
cars.drop("HP",axis=1).corr()
# Out:
#           MPG       VOL        SP        WT
# MPG  1.000000 -0.529057 -0.687125 -0.526759
# VOL -0.529057  1.000000  0.102170  0.999203
# SP  -0.687125  0.102170  1.000000  0.102439
# WT  -0.526759  0.999203  0.102439  1.000000

# %%
sns.displot(cars["HP"])

# %%
sns.displot(cars["HP"],kde=True)
plt.show()

# %%
sns.displot(cars["MPG"],kde=True)
plt.show()

# %%
sns.displot(cars["VOL"],kde=True)
plt.show()

# %%
sns.displot(cars["SP"],kde=True)
plt.show()

# %%
sns.displot(cars["WT"],kde=True)
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.boxplot(cars['HP'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(cars['MPG'])
# Out:
# <Axes: >

# %%
sns.boxplot(cars['VOL'])
# Out:
# <Axes: >

# %%
sns.boxplot(cars['SP'])
# Out:
# <Axes: >

# %%
sns.boxplot(cars['WT'])
# Out:
# <Axes: >

# %%
sns.scatterplot(cars['HP'])
# Out:
# <Axes: ylabel='HP'>

# %%
sns.scatterplot(cars['MPG'])
# Out:
# <Axes: ylabel='MPG'>

# %%
sns.scatterplot(cars['VOL'])
# Out:
# <Axes: ylabel='VOL'>

# %%
sns.scatterplot(cars['SP'])
# Out:
# <Axes: ylabel='SP'>

# %%
sns.scatterplot(cars['WT'])
# Out:
# <Axes: ylabel='WT'>

# %%
sns.barplot(cars['HP'])
# Out:
# <Axes: >

# %%
sns.barplot(cars['WT'])
# Out:
# <Axes: >

# %%
sns.barplot(cars['VOL'])
# Out:
# <Axes: >

# %%
sns.barplot(cars['MPG'])
# Out:
# <Axes: >

# %%
plt.bar(cars['HP'],cars['WT'])
# Out:
# <BarContainer object of 81 artists>

# %%
plt.bar(cars['HP'],cars['SP'])
# Out:
# <BarContainer object of 81 artists>

# %%
plt.scatter(cars['HP'],cars["WT"])

# %%
plt.scatter(cars['HP'],cars['WT'])

# %% [markdown]
# # we use scatterplot because they are numeric

# %%
plt.scatter(cars['HP'],cars['VOL'])

# %%
plt.scatter(cars['HP'],cars['MPG'])

# %%
plt.scatter(cars['HP'],cars['WT'],cars['SP'],cars['MPG'])

# %%
plt.scatter(cars['WT'],cars['VOL'])

# %%
plt.scatter(cars['WT'],cars['SP'])

# %%
plt.scatter(cars['VOL'],cars['SP'])

# %%
plt.scatter(cars['SP'],cars['WT'])

# %% [markdown]
# # WT,VOL HAVE STRONG RELATIONSHIP AND HP,WT HAVE STRONG RELATIONSHIP
